# %% [markdown]
# ### ANIKET KULKARNI, 20BRS1038, VIT-CHENNAI, ASSIGNMENT 2

# %% [markdown]
# #### Task 1

# %%
# importing the libraries

import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
# Reading the csv file
df = pd.read_csv('/content/drug200.csv')
df.head() # Visualizing the first 5 observations
# Out:
#    Age Sex      BP Cholesterol  Na_to_K   Drug
# 0   23   F    HIGH        HIGH   25.355  DrugY
# 1   47   M     LOW        HIGH   13.093  drugC
# 2   47   M     LOW        HIGH   10.114  drugC
# 3   28   F  NORMAL        HIGH    7.798  drugX
# 4   61   F     LOW        HIGH   18.043  DrugY

# %%
# Preprocessing data
# Check for missing values
print(df.isnull().sum())

# Drop rows with missing values
dataset = df.dropna()

# Check for duplicates
print(df.duplicated().sum())

# Drop duplicates
df = df.drop_duplicates()
# Out:
# Age            0
# Sex            0
# BP             0
# Cholesterol    0
# Na_to_K        0
# Drug           0
# dtype: int64
# 0

# %%
X = dataset.iloc[:,1:6]

Y = dataset['Age']

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 0)

# %%
X_train.shape
# Out:
# (160, 5)

# %%
X_test.shape
# Out:
# (40, 5)

# %%
Y_train.shape, Y_test.shape
# Out:
# ((160,), (40,))

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder() # initialize the lib

# %%
X_train['Sex'] = le.fit_transform(X_train['Sex'])
X_train['BP'] = le.fit_transform(X_train['BP'])
X_train['Cholesterol'] = le.fit_transform(X_train['Cholesterol'])
X_train['Drug'] = le.fit_transform(X_train['Drug'])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %% [markdown]
# #### Task 2

# %%
# Initializing the seq model
reg_model = Sequential()
# Adding the input layer to the model
reg_model.add(Dense(32,activation='relu'))
# Adding the 2nd hidden layer to the model
reg_model.add(Dense(16,activation='relu'))
# Adding the 3rd hidden layer to the model
reg_model.add(Dense(8,activation='relu'))
# Adding output layer
reg_model.add(Dense(1,activation='sigmoid'))

# %%
# Compile the model
reg_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Train the model
reg_model.fit(X_train, Y_train, epochs=20, batch_size=5)
# Out:
# Epoch 1/20
# 32/32 [==============================] - 1s 2ms/step - loss: -115.4878 - accuracy: 0.0000e+00
# Epoch 2/20
# 32/32 [==============================] - 0s 2ms/step - loss: -312.7695 - accuracy: 0.0000e+00
# Epoch 3/20
# 32/32 [==============================] - 0s 2ms/step - loss: -652.6171 - accuracy: 0.0000e+00
# Epoch 4/20
# 32/32 [==============================] - 0s 2ms/step - loss: -1329.0878 - accuracy: 0.0000e+00
# Epoch 5/20
# 32/32 [==============================] - 0s 2ms/step - loss: -2588.4695 - accuracy: 0.0000e+00
# Epoch 6/20
# 32/32 [==============================] - 0s 2ms/step - loss: -4777.1260 - accuracy: 0.0000e+00
# Epoch 7/20
# 32/32 [==============================] - 0s 2ms/step - loss: -8407.4434 - accuracy: 0.0000e+00
# Epoch 8/20
# 32/32 [==============================] - 0s 3ms/step - loss: -14196.4316 - accuracy: 0.0000e+00
# Epoch 9/20
# 32/32 [==============================] - 0s 2ms/step - loss: -22793.4219 - accuracy: 0.0000e+00
# Epoch 10/20
# 32/32 [==============================] - 0s 2ms/step - loss: -34893.5859 - accuracy: 0.0000e+00
# Epoch 11/20
# 32/32 [==============================] - 0s 2ms/step - loss: -51502.4648 - accuracy: 0.0000e+00
# Epoch 12/20
# 32/32 [==============================] - 0s 2ms/step - loss: -73659.3359 - accuracy: 0.0000e+00
# Epoch 13/20
# 32/32 [==============================] - 0s 2ms/step - loss: -102420.9453 - accuracy: 0.0000e+00
# Epoch 14/20
# 32/32 [==============================] - 0s 2ms/step - loss: -138309.4062 - accuracy: 0.0000e+00
# Epoch 15/20
# 32/32 [==============================] - 0s 2ms/step - loss: -183661.0312 - accuracy: 0.0000e+00
# Epoch 16/20
# 32/32 [==============================] - 0s 2ms/step - loss: -239160.9688 - accuracy: 0.0000e+00
# Epoch 17/20
# 32/32 [==============================] - 0s 2ms/step - loss: -305940.1250 - accuracy: 0.0000e+00
# Epoch 18/20
# 32/32 [==============================] - 0s 2ms/step - loss: -385432.4375 - accuracy: 0.0000e+00
# Epoch 19/20
# 32/32 [==============================] - 0s 2ms/step - loss: -480056.4375 - accuracy: 0.0000e+00
# Epoch 20/20
# 32/32 [==============================] - 0s 2ms/step - loss: -589022.8750 - accuracy: 0.0000e+00

# %% [markdown]
# #### Task 3

# %%
# Testing the model
reg_model.predict([[47,20,38,25,14]])
# Out:
# 1/1 [==============================] - 0s 348ms/step
# array([[1.]], dtype=float32)
